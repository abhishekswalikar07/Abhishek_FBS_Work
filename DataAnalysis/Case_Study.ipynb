# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('E:/FBS/DataAnalysis/Datasets/employee_performance_dataset.csv')

# %%
data
# Out:
#     Employee_ID      Name Department  Age  Gender  Years_at_Company  \
# 0         E1000      Seth      Sales   50    Male                11
# 1         E1001     Maria         IT   45    Male                 3
# 2         E1002      Mary         HR   42    Male                 1
# 3         E1003      Kyle      Sales   49    Male                12
# 4         E1004    Sandra  Marketing   28  Female                 5
# ..          ...       ...        ...  ...     ...               ...
# 495       E1495     James         IT   57  Female                 3
# 496       E1496     Jesse         IT   27    Male                 6
# 497       E1497      Sean    Finance   42  Female                 9
# 498       E1498  Nicholas  Marketing   49    Male                 1
# 499       E1499    Darren      Sales   44  Female                 4
#
#      Goals_Achieved  Projects_Completed  Trainings_Attended  Attendance_%  \
# 0                12                   5                   1     74.679836
# ...

# %%
data.head(5)
# Out:
#   Employee_ID    Name Department  Age  Gender  Years_at_Company  \
# 0       E1000    Seth      Sales   50    Male                11
# 1       E1001   Maria         IT   45    Male                 3
# 2       E1002    Mary         HR   42    Male                 1
# 3       E1003    Kyle      Sales   49    Male                12
# 4       E1004  Sandra  Marketing   28  Female                 5
#
#    Goals_Achieved  Projects_Completed  Trainings_Attended  Attendance_%  \
# 0              12                   5                   1     74.679836
# 1              10                   5                   1     91.659963
# 2              16                  10                   5     70.211989
# 3              20                   3                   3     85.427033
# 4              13                   7                   1     98.466566
#
#    Customer_Feedback  Salary(LPA)  Performance_Score
# 0                  8         8.67                7.3
# ...

# %%
data.isna().sum()
# Out:
# Employee_ID           0
# Name                  0
# Department            0
# Age                   0
# Gender                0
# Years_at_Company      0
# Goals_Achieved        0
# Projects_Completed    0
# Trainings_Attended    0
# Attendance_%          0
# Customer_Feedback     0
# Salary(LPA)           0
# Performance_Score     0
# dtype: int64

# %% [markdown]
# ## B: Exploratory Data Analysis(EDA)

# %%
data.groupby('Department')['Performance_Score'].mean()
# Out:
# Department
# Finance      7.658654
# HR           7.073404
# IT           7.702041
# Marketing    7.535714
# Sales        7.691304
# Name: Performance_Score, dtype: float64

# %%
data.sort_values('Performance_Score',ascending=False).head(10)
# Out:
#     Employee_ID      Name Department  Age  Gender  Years_at_Company  \
# 302       E1302     Carol      Sales   23    Male                 9
# 166       E1166      John         HR   39  Female                 1
# 245       E1245  Brittany  Marketing   32  Female                 7
# 252       E1252      Lisa         HR   49  Female                 7
# 467       E1467   Patrick      Sales   57  Female                 7
# 154       E1154     Kelly  Marketing   55  Female                 7
# 342       E1342     Scott    Finance   32  Female                 2
# 81        E1081    Martin         IT   22  Female                 5
# 202       E1202     Sarah         IT   52  Female                 6
# 28        E1028      Luke      Sales   37    Male                10
#
#      Goals_Achieved  Projects_Completed  Trainings_Attended  Attendance_%  \
# 302              20                   9                   3     85.724775
# ...

# %%
data.groupby('Department')['Salary(LPA)'].mean()
# Out:
# Department
# Finance      11.619423
# HR           10.774149
# IT           12.030306
# Marketing    11.666875
# Sales        11.684239
# Name: Salary(LPA), dtype: float64

# %%
data.groupby('Gender')['Performance_Score'].count()
# Out:
# Gender
# Female    248
# Male      252
# Name: Performance_Score, dtype: int64

# %%
data[['Attendance_%','Customer_Feedback','Trainings_Attended','Salary(LPA)','Performance_Score']].corr()
# Out:
#                     Attendance_%  Customer_Feedback  Trainings_Attended  \
# Attendance_%            1.000000           0.026001            0.084055
# Customer_Feedback       0.026001           1.000000           -0.051029
# Trainings_Attended      0.084055          -0.051029            1.000000
# Salary(LPA)            -0.028859           0.033866            0.003626
# Performance_Score      -0.020084           0.133088            0.167928
#
#                     Salary(LPA)  Performance_Score
# Attendance_%          -0.028859          -0.020084
# Customer_Feedback      0.033866           0.133088
# Trainings_Attended     0.003626           0.167928
# Salary(LPA)            1.000000          -0.004368
# Performance_Score     -0.004368           1.000000

# %% [markdown]
# ## C: Visualization(Matplotlib+Seaborn)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x='Department',y='Performance_Score',data=data)
# Out:
# <Axes: xlabel='Department', ylabel='Performance_Score'>

# %%
sns.boxplot(x='Department',y='Salary(LPA)',data=data)
# Out:
# <Axes: xlabel='Department', ylabel='Salary(LPA)'>

# %%
sns.histplot(x='Age',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# sns.heatmap(data.corr(),data=data)
data.head()
x=data.drop(['Employee_ID','Name','Department','Gender'],axis=1)

# %%
x.head()
# Out:
#    Age  Years_at_Company  Goals_Achieved  Projects_Completed  \
# 0   50                11              12                   5
# 1   45                 3              10                   5
# 2   42                 1              16                  10
# 3   49                12              20                   3
# 4   28                 5              13                   7
#
#    Trainings_Attended  Attendance_%  Customer_Feedback  Salary(LPA)  \
# 0                   1     74.679836                  8         8.67
# 1                   1     91.659963                  6         3.01
# 2                   5     70.211989                  9         7.95
# 3                   3     85.427033                  9         3.79
# 4                   1     98.466566                  2         9.55
#
#    Performance_Score
# 0                7.3
# 1                6.3
# 2               11.3
# 3               10.4
# 4                7.7

# %%
x.corr()
# Out:
#                          Age  Years_at_Company  Goals_Achieved  \
# Age                 1.000000          0.038936       -0.062953
# Years_at_Company    0.038936          1.000000       -0.025477
# Goals_Achieved     -0.062953         -0.025477        1.000000
# Projects_Completed -0.112671         -0.092777        0.013967
# Trainings_Attended  0.020410         -0.050672        0.006895
# Attendance_%        0.027007          0.051353       -0.009870
# Customer_Feedback   0.046645         -0.000186       -0.031071
# Salary(LPA)         0.019041         -0.001049        0.027668
# Performance_Score  -0.092848         -0.070343        0.875050
#
#                     Projects_Completed  Trainings_Attended  Attendance_%  \
# Age                          -0.112671            0.020410      0.027007
# Years_at_Company             -0.092777           -0.050672      0.051353
# Goals_Achieved                0.013967            0.006895     -0.009870
# ...

# %%
sns.heatmap(x.corr(),annot=True)
# Out:
# <Axes: >
