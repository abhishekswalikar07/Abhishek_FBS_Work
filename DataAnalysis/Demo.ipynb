# %% [markdown]
# # Demo

# %% [markdown]
# ## Day 1

# %%
a=10

# %%
a
# Out:
# 10

# %%
b=20

# %%
b
# Out:
# 20

# %%
b=10

# %%
c=a+b

# %%
c
# Out:
# 20

# %%
# pip install numpy

# %%
# pip install seaborn

# %%
# pip install --upgrade seaborn

# %%
# pip show seaborn

# %%
# pip show matplotlib

# %%
# pip install --upgrade matplotlib

# %%
# pip install --upgrade pandas

# %% [markdown]
# ## Create a function to calculate a^b

# %%
def cal(a,b):
    res=1
    for i in range(1,b+1):
        res=res*a
    return res

# %%
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
cal(a,b)
# Out:
# Enter first number: 4
# Enter second number: 5
# 1024
