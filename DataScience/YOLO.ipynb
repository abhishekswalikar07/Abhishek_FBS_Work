# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\User\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolov8n.pt')

# %%
results = model('../DataScience/YOLO/image.jpg')  # run object detection
results[0].show()   # show the result with bounding boxes
# Out:
# image 1/1 E:\FBS\DataScience\..\DataScience\YOLO\image.jpg: 448x640 1 person, 1 chair, 2 potted plants, 3 laptops, 154.1ms
# Speed: 13.5ms preprocess, 154.1ms inference, 5.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
# results
