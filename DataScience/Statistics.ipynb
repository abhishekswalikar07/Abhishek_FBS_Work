# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.Series([23,80,80,12,90,30,22,66,90,65])

# %%
data.mean()
# Out:
# np.float64(55.8)

# %%
data.median()
# Out:
# np.float64(65.5)

# %%
data.mode()
# Out:
# 0    80
# 1    90
# dtype: int64

# %%
data=pd.read_csv('Datasets/shoe_sales.csv')

# %%
data
# Out:
#          date   brand  sold_qty
# 0    9/1/2023    Nike      24.0
# 1    9/1/2023  Adidas      14.0
# 2    9/2/2023    Nike      21.0
# 3    9/2/2023  Adidas      12.0
# 4    9/3/2023    Nike      18.0
# 5    9/3/2023  Adidas      11.0
# 6    9/4/2023    Nike      22.0
# 7    9/4/2023  Adidas      13.0
# 8    9/5/2023    Nike      20.0
# 9    9/5/2023  Adidas      10.0
# 10   9/6/2023    Nike      23.0
# 11   9/6/2023  Adidas      15.0
# 12   9/7/2023    Nike      19.0
# 13   9/7/2023  Adidas      16.0
# 14   9/8/2023    Nike      17.0
# 15   9/8/2023  Adidas       8.0
# 16   9/9/2023    Nike      25.0
# 17   9/9/2023  Adidas      17.0
# 18  9/10/2023    Nike      14.0
# 19  9/10/2023  Adidas       7.0
# 20  9/11/2023    Nike      23.0
# 21  9/11/2023  Adidas       9.0
# 22  9/12/2023    Nike      19.0
# 23  9/12/2023  Adidas     689.0
# 24  9/13/2023    Nike      16.0
# 25  9/13/2023  Adidas      11.0
# 26  9/14/2023    Nike      22.0
# 27  9/14/2023  Adidas      13.0
# ...

# %%
data.head()
# Out:
#        date   brand  sold_qty
# 0  9/1/2023    Nike      24.0
# 1  9/1/2023  Adidas      14.0
# 2  9/2/2023    Nike      21.0
# 3  9/2/2023  Adidas      12.0
# 4  9/3/2023    Nike      18.0

# %%
data.shape
# Out:
# (60, 3)

# %%
data['brand'].unique()
# Out:
# array(['Nike', 'Adidas'], dtype=object)

# %%
data['brand'].value_counts()
# Out:
# brand
# Nike      30
# Adidas    30
# Name: count, dtype: int64

# %%
data.isna().sum()
# Out:
# date        0
# brand       0
# sold_qty    2
# dtype: int64

# %%
data[data['sold_qty'].isna()]
# Out:
#          date brand  sold_qty
# 32  9/17/2023  Nike       NaN
# 48  9/25/2023  Nike       NaN

# %%
data1=data[data['brand']=='Nike']['sold_qty'].mean()
data1
# Out:
# np.float64(19.642857142857142)

# %%
data['sold_qty'].fillna(data1,inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12304\2322602150.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['sold_qty'].fillna(data1,inplace=True)

# %%
data=pd.read_excel('Datasets/fitness_data.xlsx')
data.head()
# Out:
#      name  steps_taken  calories_burned  sleep_duration(hours)  \
# 0  Akshay        10500             4500                    7.5
# 1   Priya         9800             4200                    7.2
# 2     Raj        11500             4800                    7.0
# 3   Emily        12000             5000                    7.8
# 4   Rohit         8900             4000                    7.0
#
#    water_intake(ounces)
# 0                    80
# 1                    75
# 2                    90
# 3                    85
# 4                    70

# %%
sns.histplot(x='sleep_duration(hours)',data=data,kde=True)
mean=data['sleep_duration(hours)'].mean()
std=data['sleep_duration(hours)'].std()
plt.axvline(mean,color='red')
plt.axvline(mean-3*std,color='green')
plt.axvline(mean+3*std,color='green')

# %%
std3=mean+3*std
std3
# Out:
# np.float64(12.378853866316092)

# %%
data[data['sleep_duration(hours)']>std3]
# Out:
#      name  steps_taken  calories_burned  sleep_duration(hours)  \
# 21  Elena        11700             4900                   18.0
#
#     water_intake(ounces)
# 21                   100

# %%
data=pd.read_csv('Datasets/shoe_sales.csv')

# %%
data
# Out:
#          date   brand  sold_qty
# 0    9/1/2023    Nike      24.0
# 1    9/1/2023  Adidas      14.0
# 2    9/2/2023    Nike      21.0
# 3    9/2/2023  Adidas      12.0
# 4    9/3/2023    Nike      18.0
# 5    9/3/2023  Adidas      11.0
# 6    9/4/2023    Nike      22.0
# 7    9/4/2023  Adidas      13.0
# 8    9/5/2023    Nike      20.0
# 9    9/5/2023  Adidas      10.0
# 10   9/6/2023    Nike      23.0
# 11   9/6/2023  Adidas      15.0
# 12   9/7/2023    Nike      19.0
# 13   9/7/2023  Adidas      16.0
# 14   9/8/2023    Nike      17.0
# 15   9/8/2023  Adidas       8.0
# 16   9/9/2023    Nike      25.0
# 17   9/9/2023  Adidas      17.0
# 18  9/10/2023    Nike      14.0
# 19  9/10/2023  Adidas       7.0
# 20  9/11/2023    Nike      23.0
# 21  9/11/2023  Adidas       9.0
# 22  9/12/2023    Nike      19.0
# 23  9/12/2023  Adidas     689.0
# 24  9/13/2023    Nike      16.0
# 25  9/13/2023  Adidas      11.0
# 26  9/14/2023    Nike      22.0
# 27  9/14/2023  Adidas      13.0
# ...

# %%
data.shape
# Out:
# (60, 3)

# %%
data['brand'].unique()
# Out:
# array(['Nike', 'Adidas'], dtype=object)

# %%
data.isna().sum()
# Out:
# date        0
# brand       0
# sold_qty    2
# dtype: int64

# %%
data[data['sold_qty'].isna()]
# Out:
#          date brand  sold_qty
# 32  9/17/2023  Nike       NaN
# 48  9/25/2023  Nike       NaN

# %%
data1=data[data['brand']=='Nike']['sold_qty'].mean()
data1
# Out:
# np.float64(19.642857142857142)

# %%
data['sold_qty'].fillna(data1,inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12304\2322602150.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['sold_qty'].fillna(data1,inplace=True)

# %%
data
# Out:
#          date   brand    sold_qty
# 0    9/1/2023    Nike   24.000000
# 1    9/1/2023  Adidas   14.000000
# 2    9/2/2023    Nike   21.000000
# 3    9/2/2023  Adidas   12.000000
# 4    9/3/2023    Nike   18.000000
# 5    9/3/2023  Adidas   11.000000
# 6    9/4/2023    Nike   22.000000
# 7    9/4/2023  Adidas   13.000000
# 8    9/5/2023    Nike   20.000000
# 9    9/5/2023  Adidas   10.000000
# 10   9/6/2023    Nike   23.000000
# 11   9/6/2023  Adidas   15.000000
# 12   9/7/2023    Nike   19.000000
# 13   9/7/2023  Adidas   16.000000
# 14   9/8/2023    Nike   17.000000
# 15   9/8/2023  Adidas    8.000000
# 16   9/9/2023    Nike   25.000000
# 17   9/9/2023  Adidas   17.000000
# 18  9/10/2023    Nike   14.000000
# 19  9/10/2023  Adidas    7.000000
# 20  9/11/2023    Nike   23.000000
# 21  9/11/2023  Adidas    9.000000
# 22  9/12/2023    Nike   19.000000
# 23  9/12/2023  Adidas  689.000000
# 24  9/13/2023    Nike   16.000000
# 25  9/13/2023  Adidas   11.000000
# ...

# %%
data.isna().sum()
# Out:
# date        0
# brand       0
# sold_qty    0
# dtype: int64

# %%
data.head()
# Out:
#        date   brand  sold_qty
# 0  9/1/2023    Nike      24.0
# 1  9/1/2023  Adidas      14.0
# 2  9/2/2023    Nike      21.0
# 3  9/2/2023  Adidas      12.0
# 4  9/3/2023    Nike      18.0

# %%
sns.histplot(x='sold_qty',data=data,kde=True)
mean=data['sold_qty'].mean()
std=data['sold_qty'].std()
plt.axvline(mean,color='red')
plt.axvline(mean-3*std,color='green')
plt.axvline(mean+3*std,color='green')

# %%
std3=mean+3*std
std3
# Out:
# np.float64(288.2758686171575)

# %%
data[data['sold_qty']>std3]
# Out:
#          date   brand  sold_qty
# 23  9/12/2023  Adidas     689.0

# %%
data.head()
# Out:
#        date   brand  sold_qty
# 0  9/1/2023    Nike      24.0
# 1  9/1/2023  Adidas      14.0
# 2  9/2/2023    Nike      21.0
# 3  9/2/2023  Adidas      12.0
# 4  9/3/2023    Nike      18.0

# %%
data.describe()
# Out:
#          sold_qty
# count   60.000000
# mean    27.221429
# std     87.018147
# min      7.000000
# 25%     12.750000
# 50%     16.000000
# 75%     19.732143
# max    689.000000

# %%
sns.boxplot(x='brand',y='sold_qty',data=data)
q1=data['sold_qty'].quantile(.25)
q2=data['sold_qty'].quantile(.5)
q3=data['sold_qty'].quantile(.75)
IQR=q3-q1
lower_bound=q1-(1.5*IQR)
upper_bound=q3+(1.5*IQR)
# plt.axhline(q1,color='purple')
# plt.axhline(q2,color='yellow')
# plt.axhline(q1,color='green')

# %%
data[data['sold_qty']<lower_bound]
# Out:
# Empty DataFrame
# Columns: [date, brand, sold_qty]
# Index: []

# %%
data[data['sold_qty']>upper_bound]
# Out:
#          date   brand  sold_qty
# 23  9/12/2023  Adidas     689.0

# %%
data=pd.read_excel('Datasets/fitness_data.xlsx')

# %%
data.head()
# Out:
#      name  steps_taken  calories_burned  sleep_duration(hours)  \
# 0  Akshay        10500             4500                    7.5
# 1   Priya         9800             4200                    7.2
# 2     Raj        11500             4800                    7.0
# 3   Emily        12000             5000                    7.8
# 4   Rohit         8900             4000                    7.0
#
#    water_intake(ounces)
# 0                    80
# 1                    75
# 2                    90
# 3                    85
# 4                    70

# %%
data['calories_burned'].value_counts()
# Out:
# calories_burned
# 4200    6
# 4600    6
# 4000    5
# 4700    5
# 4500    4
# 4400    4
# 4300    4
# 4900    4
# 4800    3
# 3800    2
# 4100    2
# 3900    2
# 5000    1
# 3700    1
# 5500    1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
# sns.boxplot(x='sleep_duration(hours)',data=data,y='calories_burned')
sns.boxplot(y='calories_burned', x='sleep_duration(hours)', data=data)
plt.xticks(rotation=90)
plt.show()

q1=data['sleep_duration(hours)'].quantile(.25)
q2=data['sleep_duration(hours)'].quantile(.5)
q3=data['sleep_duration(hours)'].quantile(.75)
IQR=q3-q1
lower_bound=q1-(1.5*IQR)
upper_bound=q3+(1.5*IQR)
# plt.axvline(q1,color='orange')
# plt.axvline(q2,color='yellow')
# plt.axvline(q3,color='green')

# %% [markdown]
# # Label Encoding

# %%
data=pd.read_csv('../DataAnalysis/Datasets/cars93.csv')

# %%
data.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
data['Type'].unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data['Type']=le.fit_transform(data['Type'])

# %%
data.head()
# Out:
#   Manufacturer    Model  Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra     3   15.9        25         Driver only
# 1        Acura   Legend     2   33.9        18  Driver & Passenger
# 2         Audi       90     0   29.1        20         Driver only
# 3         Audi      100     2   37.7        19  Driver & Passenger
# 4          BMW     535i     2   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %% [markdown]
# # Ordinal Encoding

# %%
data=pd.read_csv('../DataAnalysis/Datasets/cars93.csv')

# %%
data.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
data['Type'].unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
ord=OrdinalEncoder(categories=[['Compact','Sporty','Small','Midsize','Van','Large']])
data['Type']=ord.fit_transform(data[['Type']]).astype('int')

# %%
data.head()
# Out:
#   Manufacturer    Model  Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra     2   15.9        25         Driver only
# 1        Acura   Legend     3   33.9        18  Driver & Passenger
# 2         Audi       90     0   29.1        20         Driver only
# 3         Audi      100     3   37.7        19  Driver & Passenger
# 4          BMW     535i     3   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %% [markdown]
# # OneHot Encoding

# %%
data=pd.DataFrame({'Type':['B','V','C','K','B','K','V','B','V','K'],
                  'Size':['S','M','L','S','M','L','S','M','L','M'],
                  'Qnt':[2,3,4,5,1,2,3,5,2,2]})

# %%
data.head()
# Out:
#   Type Size  Qnt
# 0    B    S    2
# 1    V    M    3
# 2    C    L    4
# 3    K    S    5
# 4    B    M    1

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder()
result=ohe.fit_transform(data[['Type']]).toarray()
result=pd.DataFrame(result,columns=['B','C','K','V'])
data1=pd.concat([data,result],axis=1)
data1.drop('Type',axis=1,inplace=True)
data1
# Out:
#   Size  Qnt    B    C    K    V
# 0    S    2  1.0  0.0  0.0  0.0
# 1    M    3  0.0  0.0  0.0  1.0
# 2    L    4  0.0  1.0  0.0  0.0
# 3    S    5  0.0  0.0  1.0  0.0
# 4    M    1  1.0  0.0  0.0  0.0
# 5    L    2  0.0  0.0  1.0  0.0
# 6    S    3  0.0  0.0  0.0  1.0
# 7    M    5  1.0  0.0  0.0  0.0
# 8    L    2  0.0  0.0  0.0  1.0
# 9    M    2  0.0  0.0  1.0  0.0

# %%
data.head()
# Out:
#   Type Size  Qnt
# 0    B    S    2
# 1    V    M    3
# 2    C    L    4
# 3    K    S    5
# 4    B    M    1

# %%
data1=pd.get_dummies(data,columns=['Type'],dtype='int')
# data1=pd.get_dummies(data,columns=['Type'],dtype='int',drop_first=True)

# %%
data1
# Out:
#   Size  Qnt  Type_B  Type_C  Type_K  Type_V
# 0    S    2       1       0       0       0
# 1    M    3       0       0       0       1
# 2    L    4       0       1       0       0
# 3    S    5       0       0       1       0
# 4    M    1       1       0       0       0
# 5    L    2       0       0       1       0
# 6    S    3       0       0       0       1
# 7    M    5       1       0       0       0
# 8    L    2       0       0       0       1
# 9    M    2       0       0       1       0
