# %%
pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 2.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#     --------------------------------------- 0.8/39.0 MB 4.2 MB/s eta 0:00:10
#    - -------------------------------------- 1.6/39.0 MB 4.2 MB/s eta 0:00:09
#    -- ------------------------------------- 2.6/39.0 MB 4.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.2/39.0 MB 5.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.8/39.0 MB 5.9 MB/s eta 0:00:06
#    ------- -------------------------------- 7.6/39.0 MB 6.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.0/39.0 MB 7.1 MB/s eta 0:00:05
#    ------------ --------------------------- 12.6/39.0 MB 7.8 MB/s eta 0:00:04
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\SHREE\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.pt')

# %%
results = model('image1.jpg')  # run object detection
results[0].show()             # show the result with bounding boxes
# Out:
# image 1/1 D:\My Codes\Data Science\Practice\YOLO\image1.jpg: 640x608 1 cat, 1 sports ball, 148.8ms
# Speed: 22.7ms preprocess, 148.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
