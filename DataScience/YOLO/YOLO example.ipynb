# %%
# pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
results = model('sandwitch.jpg')  # run object detection
results[0].show()             # show the result with bounding boxes

# %%
results
