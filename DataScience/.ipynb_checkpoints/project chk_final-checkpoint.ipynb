# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
data = pd.read_csv("social_media_viral_content_dataset.csv")

# %%
data.head()
# Out:
#      post_id        platform content_type       topic language  region  \
# 0  SM_100000       Instagram         text      Sports       ur      UK
# 1  SM_100001       Instagram     carousel      Sports       ur  Brazil
# 2  SM_100002  YouTube Shorts        video  Technology       ur      UK
# 3  SM_100003               X         text    Politics       ur      US
# 4  SM_100004  YouTube Shorts         text   Education       es      US
#
#          post_datetime                         hashtags    views   likes  \
# 0  2024-12-10 00:00:00              #tech #funny #music  2319102  122058
# 1  2024-10-13 00:00:00  #news #fyp #funny #ai #trending  2538464  110368
# 2  2024-05-03 00:00:00                        #ai #news  1051176   87598
# 3  2024-08-04 00:00:00                       #ai #funny  5271440  329465
# 4  2024-03-28 00:00:00     #news #ai #viral #funny #fyp  3186256  199141
#
#    comments  shares  engagement_rate  sentiment_score  is_viral
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   post_id          2000 non-null   object
#  1   platform         2000 non-null   object
#  2   content_type     2000 non-null   object
#  3   topic            2000 non-null   object
#  4   language         2000 non-null   object
#  5   region           2000 non-null   object
#  6   post_datetime    2000 non-null   object
#  7   hashtags         2000 non-null   object
#  8   views            2000 non-null   int64
#  9   likes            2000 non-null   int64
#  10  comments         2000 non-null   int64
#  11  shares           2000 non-null   int64
#  12  engagement_rate  2000 non-null   float64
#  13  sentiment_score  2000 non-null   float64
#  14  is_viral         2000 non-null   int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 234.5+ KB

# %%
data.drop(columns=['post_datetime', 'hashtags', 'post_id'], inplace=True)

# %%
data.head()
# Out:
#          platform content_type       topic language  region    views   likes  \
# 0       Instagram         text      Sports       ur      UK  2319102  122058
# 1       Instagram     carousel      Sports       ur  Brazil  2538464  110368
# 2  YouTube Shorts        video  Technology       ur      UK  1051176   87598
# 3               X         text    Politics       ur      US  5271440  329465
# 4  YouTube Shorts         text   Education       es      US  3186256  199141
#
#    comments  shares  engagement_rate  sentiment_score  is_viral
# 0     15800     861           0.0598            0.464         1
# 1     11289   54887           0.0695           -0.800         1
# 2     47196   44132           0.1702            0.416         0
# 3       774   59736           0.0740            0.877         1
# 4      5316   83105           0.0903            0.223         1

# %%
data.isna().sum()
# Out:
# platform           0
# content_type       0
# topic              0
# language           0
# region             0
# views              0
# likes              0
# comments           0
# shares             0
# engagement_rate    0
# sentiment_score    0
# is_viral           0
# dtype: int64

# %%
def chkoutlier(data, col):

    plt.subplot(1,2,1)
    plt.boxplot(data[col])
    plt.title(f"Boxplot of {col}")

    plt.subplot(1,2,2)
    sns.histplot(x=data[col], kde=True)
    plt.axvline(data[col].mean() + 3*data[col].std(), color='red')
    plt.axvline(data[col].mean() - 3*data[col].std(), color='red')
    plt.title(f"Histogram of {col}")

    plt.tight_layout()  ###v Automatically adjusts spacing so titles, labels, and plots don’t overlap.
    plt.show()

# %%
chkoutlier(data, 'views')

# %%
chkoutlier(data, 'likes')

# %%
chkoutlier(data, 'comments')

# %%
chkoutlier(data, 'shares')

# %%
chkoutlier(data, 'engagement_rate')

# %%
chkoutlier(data, 'sentiment_score')

# %% [markdown]
# ### Handle outlisers fun code

# %%
def handleOut(data, col):
    q3 = data[col].quantile(0.75)
    q1 = data[col].quantile(0.25)
    iqr = q3 - q1
    upper = q3 + (1.5 * iqr)
    lower = q1 - (1.5 * iqr)
    data.loc[data[col] > upper, col] = upper
    data.loc[data[col] < lower, col] = lower

# %%
handleOut(data, 'engagement_rate')

# %%
handleOut(data, 'views')

# %%
num_cols = ['engagement_rate', 'views' ]

for col in num_cols:
    chkoutlier(data, col)

# %%
cols = ['platform','content_type','topic','language','region']

for col in cols:
    print(f"Column: {col}")
    print("Unique Values:", data[col].unique())
# Out:
# Column: platform
# Unique Values: ['Instagram' 'YouTube Shorts' 'X' 'TikTok']
# Column: content_type
# Unique Values: ['text' 'carousel' 'video' 'image']
# Column: topic
# Unique Values: ['Sports' 'Technology' 'Politics' 'Education' 'Entertainment' 'Lifestyle']
# Column: language
# Unique Values: ['ur' 'es' 'hi' 'en' 'fr']
# Column: region
# Unique Values: ['UK' 'Brazil' 'US' 'Pakistan' 'India']

# %%
# cols = ['platform','content_type','topic','language','region']
# le = LabelEncoder()
# for col in cols:
#     data[col] = le.fit_transform(data[col])

encoders = {}

cols = ['platform','content_type','topic','language','region']

for col in cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    encoders[col] = le

# %%
data.head()
# Out:
#    platform  content_type  topic  language  region    views   likes  comments  \
# 0         0             2      4         4       3  2319102  122058     15800
# 1         0             0      4         4       0  2538464  110368     11289
# 2         3             3      5         4       3  1051176   87598     47196
# 3         2             2      3         4       4  5271440  329465       774
# 4         3             2      0         1       4  3186256  199141      5316
#
#    shares  engagement_rate  sentiment_score  is_viral
# 0     861           0.0598            0.464         1
# 1   54887           0.0695           -0.800         1
# 2   44132           0.1702            0.416         0
# 3   59736           0.0740            0.877         1
# 4   83105           0.0903            0.223         1

# %%
data.describe()
# Out:
#           platform  content_type        topic     language       region  \
# count  2000.000000   2000.000000  2000.000000  2000.000000  2000.000000
# mean      1.472000      1.452000     2.473000     1.991500     2.015500
# std       1.134839      1.117282     1.720393     1.427041     1.433976
# min       0.000000      0.000000     0.000000     0.000000     0.000000
# 25%       0.000000      0.000000     1.000000     1.000000     1.000000
# 50%       1.000000      1.000000     2.000000     2.000000     2.000000
# 75%       2.000000      2.000000     4.000000     3.000000     3.000000
# max       3.000000      3.000000     5.000000     4.000000     4.000000
#
#               views          likes      comments        shares  \
# count  2.000000e+03    2000.000000   2000.000000   2000.000000
# mean   4.282895e+06  245329.244000  24786.929000  49936.981500
# std    3.240461e+06  145032.423582  14433.288364  29012.818697
# min    4.380000e+03     292.000000     14.000000    127.000000
# ...

# %%
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
# data["total_engagement"] = data["likes"] + data["comments"] + data["shares"]

# %%
data.head()
# Out:
#    platform  content_type  topic  language  region    views   likes  comments  \
# 0         0             2      4         4       3  2319102  122058     15800
# 1         0             0      4         4       0  2538464  110368     11289
# 2         3             3      5         4       3  1051176   87598     47196
# 3         2             2      3         4       4  5271440  329465       774
# 4         3             2      0         1       4  3186256  199141      5316
#
#    shares  engagement_rate  sentiment_score  is_viral
# 0     861           0.0598            0.464         1
# 1   54887           0.0695           -0.800         1
# 2   44132           0.1702            0.416         0
# 3   59736           0.0740            0.877         1
# 4   83105           0.0903            0.223         1

# %%
x = data.drop('is_viral', axis=1)
y = data['is_viral']

# %%
## SMOTE

# %%
y.value_counts()
# Out:
# is_viral
# 1    1398
# 0     602
# Name: count, dtype: int64

# %%
sm = SMOTE()

# %%
x, y = sm.fit_resample(x, y)

# %%
x.shape
# Out:
# (2796, 11)

# %%
y.value_counts()
# Out:
# is_viral
# 1    1398
# 0    1398
# Name: count, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=42)

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Training Accuracy
train_acc = rf.score(x_train, y_train)

# Testing Accuracy
test_acc = rf.score(x_test, y_test)

print(f"Training Accuracy : {train_acc}")
print(f"Testing Accuracy  : {test_acc}")
# Out:
# Training Accuracy : 1.0
# Testing Accuracy  : 1.0

# %%
y_pred = rf.predict(x_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[296,   0],
#        [  0, 264]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       296
#            1       1.00      1.00      1.00       264
#
#     accuracy                           1.00       560
#    macro avg       1.00      1.00      1.00       560
# weighted avg       1.00      1.00      1.00       560

# %%
# predict_viral()

# %%
# platform_map = {"instagram": 0, "facebook": 1, "x": 2, "youtube shorts": 3}

# content_map = {"text": 0, "carousel": 1, "image": 2, "video": 3}

# topic_map = {"sports": 0, "politics": 1, "education": 2, "technology": 3, "entertainment": 4}

# language_map = {"en": 0, "es": 1, "hi": 2, "fr": 3, "ur": 4}

# region_map = {"us": 0, "india": 1, "uk": 2, "canada": 3, "brazil": 4}

# %%
# def predict_viral():

#     print("\n====== ENTER POST DETAILS ======\n")

#     print("Platform options: instagram, facebook, x, youtube shorts")
#     platform = input("Enter Platform: ").lower()

#     print("\nContent Type options: text, carousel, image, video")
#     content_type = input("Enter Content Type: ").lower()

#     print("\nTopic options: sports, politics, education, technology, entertainment")
#     topic = input("Enter Topic: ").lower()

#     print("\nLanguage options: en, es, hi, fr, ur")
#     language = input("Enter Language: ").lower()

#     print("\nRegion options: us, india, uk, canada, brazil")
#     region = input("Enter Region: ").lower()


#     views = int(input("\nViews: "))
#     likes = int(input("Likes: "))
#     comments = int(input("Comments: "))
#     shares = int(input("Shares: "))
#     engagement_rate = float(input("Engagement Rate: "))
#     sentiment_score = float(input("Sentiment Score: "))


#     # Convert string → encoded numbers
#     platform = platform_map[platform]
#     content = content_map[content_type]
#     topic = topic_map[topic]
#     language = language_map[language]
#     region = region_map[region]


#     # Feature order SAME as training
#     user_data = [[platform, content_type, topic, language, region, views, likes, comments, shares, engagement_rate, sentiment_score ]]

#     res = rf.predict(user_data)

#     print("\n===== RESULT =====")

#     if res[0] == 1:
#         print(" Post is Viral")
#     else:
#         print(" Post is Not Viral")

# %%
import pickle

# %%
with open('viral_model.pkl','wb') as f:
    pickle.dump(rf, f)

# %%
x.head()
# Out:
#    platform  content_type  topic  language  region    views   likes  comments  \
# 0         0             2      4         4       3  2319102  122058     15800
# 1         0             0      4         4       0  2538464  110368     11289
# 2         3             3      5         4       3  1051176   87598     47196
# 3         2             2      3         4       4  5271440  329465       774
# 4         3             2      0         1       4  3186256  199141      5316
#
#    shares  engagement_rate  sentiment_score
# 0     861           0.0598            0.464
# 1   54887           0.0695           -0.800
# 2   44132           0.1702            0.416
# 3   59736           0.0740            0.877
# 4   83105           0.0903            0.223
