# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# datagen = ImageDataGenerator(rescale=1./255)
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = datagen.flow_from_directory(
    '../../Animal_Dataset/Training_set/',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'   # CHANGED
)

test_generator = datagen.flow_from_directory(
    '../../Animal_Dataset/Testing_set/',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'   # CHANGED
)
# Out:
# Found 4000 images belonging to 4 classes.
# Found 4000 images belonging to 4 classes.

# %%
train_generator

# %%
data,label=next(train_generator) # Generates 32 images and their labels from out training data
data.shape
# Out:
# (32, 64, 64, 3)

# %%
plt.figure(figsize=(3,3))
plt.imshow(data[20]) # Takes 32 images at one time
plt.title(f'Label:{label[20]}') # Take label of first image & show it as title of image
plt.show()

# %%
cnn = tf.keras.models.Sequential()

cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64,64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Flatten())

cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# IMPORTANT CHANGE → 4 output neurons
cnn.add(tf.keras.layers.Dense(units=4, activation='softmax'))
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 62, 62, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 29, 29, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ...

# %%
# history=cnn.fit(x=train_generator,epochs=10)
history = cnn.fit(
    x=train_generator,
    epochs=10,
    validation_data=test_generator
)
# Out:
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.5213 - loss: 1.0574 - val_accuracy: 0.6812 - val_loss: 0.7951
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 35s 278ms/step - accuracy: 0.6998 - loss: 0.7563 - val_accuracy: 0.7190 - val_loss: 0.7016
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 34s 274ms/step - accuracy: 0.7113 - loss: 0.7199 - val_accuracy: 0.7318 - val_loss: 0.6897
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 34s 275ms/step - accuracy: 0.7452 - loss: 0.6527 - val_accuracy: 0.7535 - val_loss: 0.6184
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 36s 292ms/step - accuracy: 0.7530 - loss: 0.6236 - val_accuracy: 0.7757 - val_loss: 0.5699
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 319ms/step - accuracy: 0.7747 - loss: 0.5787 - val_accuracy: 0.7862 - val_loss: 0.5457
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.7797 - loss: 0.5675 - val_accuracy: 0.7805 - val_loss: 0.5482
# Epoch 8/10
# ...

# %%
cnn.evaluate(test_generator)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 133ms/step - accuracy: 0.8018 - loss: 0.5067
# [0.5066558122634888, 0.8017500042915344]

# %%
pred = cnn.predict(test_generator)

predicted_classes = np.argmax(pred, axis=1)

true_classes = test_generator.classes

print(predicted_classes)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step
# [0 0 3 ... 2 1 0]

# %%
predicted_classes
# Out:
# array([0, 0, 3, ..., 2, 1, 0], shape=(4000,))

# %%
from keras.utils import load_img, img_to_array

new_image = load_img('../../Animal_Dataset/Predict/Rhino_3.jpg', target_size=(64,64))
new_image = img_to_array(new_image)
new_image = new_image / 255
new_image = np.expand_dims(new_image, axis=0)

result = cnn.predict(new_image)
print(result)
predicted_class = np.argmax(result)

class_labels = list(train_generator.class_indices.keys())

print("Predicted Animal:", class_labels[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# [[0.00893167 0.2133414  0.61243767 0.16528922]]
# Predicted Animal: Rhino

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train','Validation'])
plt.show()
