# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('../DataScience/Datasets/Position_Salaries.csv')

# %%
data.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
X=data[['Level']]
y=data['Salary']

# %% [markdown]
# ## Check with linear regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
pred=lr.predict(X)

# %%
from sklearn.metrics import r2_score
r2_score(y,pred)
# Out:
# 0.6690412331929895

# %%
import matplotlib.pyplot as plt
plt.scatter(data['Level'],data['Salary'])
plt.plot(data['Level'],pred)

# %% [markdown]
# ## Implementing polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=4)

# %%
X_trans=poly.fit_transform(X)

# %%
lr=LinearRegression()

# %%
lr.fit(X_trans,y)
# Out:
# LinearRegression()

# %%
poly_predict=lr.predict(X_trans)

# %%
r2_score(y,poly_predict)
# Out:
# 0.9973922891706614

# %%
plt.figure(figsize=(6,4))
plt.scatter(data['Level'],data['Salary'])
# plt.plot(data['Level'],poly_predict,marker='p',markerfacecolor='red')
plt.plot(data['Level'],poly_predict)
plt.show()

# %%
level=6
# values=[[1,6,36,216,1296]]
values=poly.transform([[level]])
lr.predict(values)
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([143275.05827509])
