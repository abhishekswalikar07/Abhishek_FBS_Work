# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# For reproducibility
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("Datasets/Heart.csv")
data.head()

print(data.shape)
data.info()
# Out:
# (303, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %% [markdown]
# # EDA

# %%
data.shape
# Out:
# (303, 15)

# %%
data['AHD'].value_counts()
# Out:
# AHD
# No     164
# Yes    139
# Name: count, dtype: int64

# %%
data[data['Ca'].isna() | data['Thal'].isna()]
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 87           88   53    0    nonanginal     128   216    0        2    115
# 166         167   52    1    nonanginal     138   223    0        0    169
# 192         193   43    1  asymptomatic     132   247    1        2    143
# 266         267   52    1  asymptomatic     128   204    1        0    156
# 287         288   58    1    nontypical     125   220    0        0    144
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 87       0      0.0      1  0.0         NaN   No
# 166      0      0.0      1  NaN      normal   No
# 192      1      0.1      2  NaN  reversable  Yes
# 266      1      1.0      2  0.0         NaN  Yes
# 287      0      0.4      2  NaN  reversable   No
# 302      0      0.0      1  NaN      normal   No

# %%
data['Ca'].value_counts()
# Out:
# Ca
# 0.0    176
# 1.0     65
# 2.0     38
# 3.0     20
# Name: count, dtype: int64

# %%
data['Thal'].value_counts()
# Out:
# Thal
# normal        166
# reversable    117
# fixed          18
# Name: count, dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (297, 15)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sns.histplot(data=data,x='RestBP',kde=True)
# plt.axvline(data['RestBP'].mean()+(3*data['RestBP'].std()),color='red')

# %%
def checkOutliers(data, col):
    plt.figure(figsize=(12,4))   # bigger figure

    plt.subplot(1, 2, 1)
    plt.boxplot(data[col])
    plt.title(f"Boxplot of {col}")
    plt.tight_layout(pad=3)      # space from borders

    plt.subplot(1, 2, 2)
    sns.histplot(data=data, x=col, kde=True)
    
    mean = data[col].mean()
    std = data[col].std()
    
    plt.axvline(mean + 3*std, color='red', linestyle='--')
    plt.axvline(mean - 3*std, color='red', linestyle='--')
    plt.title(f"Histogram of {col}")

    plt.tight_layout(pad=3)      # space between plots
    plt.show()

# %%
def handleOutliers(data,col):
    q3=data[col].quantile(0.75)
    q1=data[col].quantile(0.25)
    iqr=q3-q1
    upper=q3+(1.5*iqr)
    lower=q1-(1.5*iqr)
    data.loc[data[col]>upper,col]=upper
    data.loc[data[col]<lower,col]=lower

# %%
data.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
data['ChestPain'].unique()
# Out:
# array(['typical', 'asymptomatic', 'nonanginal', 'nontypical'],
#       dtype=object)

# %%
data['ChestPain']=data['ChestPain'].replace({'typical':0, 'asymptomatic':1, 'nonanginal':2, 'nontypical':3})

# %%
data['Thal'].unique()
# Out:
# array(['fixed', 'normal', 'reversable'], dtype=object)

# %%
data['Thal']=data['Thal'].replace({'fixed':0, 'normal':1, 'reversable':2})

# %%
data.head()
# Out:
#    Unnamed: 0  Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0           1   63    1          0     145   233    1        2    150      0
# 1           2   67    1          1     160   286    0        2    108      1
# 2           3   67    1          1     120   229    0        2    129      1
# 3           4   37    1          2     130   250    0        0    187      0
# 4           5   41    0          3     130   204    0        2    172      0
#
#    Oldpeak  Slope   Ca  Thal  AHD
# 0      2.3      3  0.0     0   No
# 1      1.5      2  3.0     1  Yes
# 2      2.6      2  2.0     2  Yes
# 3      3.5      3  0.0     1   No
# 4      1.4      1  0.0     1   No

# %%
checkOutliers(data,'RestBP')
checkOutliers(data,'Chol')
checkOutliers(data,'MaxHR')
checkOutliers(data,'ExAng')
checkOutliers(data,'Oldpeak')
checkOutliers(data,'RestECG')

# %%
handleOutliers(data,'RestBP')
handleOutliers(data,'Chol')
handleOutliers(data,'MaxHR')
handleOutliers(data,'ExAng')
handleOutliers(data,'Oldpeak')
handleOutliers(data,'RestECG')

# %%
checkOutliers(data,'RestBP')
checkOutliers(data,'Chol')
checkOutliers(data,'MaxHR')
checkOutliers(data,'ExAng')
checkOutliers(data,'Oldpeak')
checkOutliers(data,'RestECG')

# %% [markdown]
# # Feature Engineering

# %%
data.head()
# Out:
#    Unnamed: 0  Age  Sex  ChestPain  RestBP   Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0           1   63    1          0     145  233.0    1        2  150.0    0.0
# 1           2   67    1          1     160  286.0    0        2  108.0    1.0
# 2           3   67    1          1     120  229.0    0        2  129.0    1.0
# 3           4   37    1          2     130  250.0    0        0  187.0    0.0
# 4           5   41    0          3     130  204.0    0        2  172.0    0.0
#
#    Oldpeak  Slope   Ca  Thal  AHD
# 0      2.3      3  0.0     0   No
# 1      1.5      2  3.0     1  Yes
# 2      2.6      2  2.0     2  Yes
# 3      3.5      3  0.0     1   No
# 4      1.4      1  0.0     1   No

# %%
data.describe()
# Out:
#        Unnamed: 0         Age         Sex   ChestPain      RestBP        Chol  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean   150.673401   54.542088    0.676768    1.531987  131.343434  246.260943
# std     87.323283    9.049736    0.468500    0.858082   16.801401   47.836752
# min      1.000000   29.000000    0.000000    0.000000   94.000000  126.000000
# 25%     75.000000   48.000000    0.000000    1.000000  120.000000  211.000000
# 50%    150.000000   56.000000    1.000000    1.000000  130.000000  243.000000
# 75%    226.000000   61.000000    1.000000    2.000000  140.000000  276.000000
# max    302.000000   77.000000    1.000000    3.000000  170.000000  373.500000
#
#               Fbs     RestECG       MaxHR       ExAng     Oldpeak       Slope  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.144781    0.996633  149.641414    0.326599    1.040067    1.602694
# std      0.352474    0.994914   22.807957    0.469761    1.114574    0.618187
# min      0.000000    0.000000   83.500000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000  133.000000    0.000000    0.000000    1.000000
# 50%      0.000000    1.000000  153.000000    0.000000    0.800000    2.000000
# 75%      0.000000    2.000000  166.000000    1.000000    1.600000    2.000000
# max      1.000000    2.000000  202.000000    1.000000    4.000000    3.000000
#
#                Ca        Thal
# count  297.000000  297.000000
# mean     0.676768    1.326599
# std      0.938965    0.585061
# min      0.000000    0.000000
# 25%      0.000000    1.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# max      3.000000    2.000000

# %%
# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# data['AHD']=le.fit_transform(data['AHD'])

# %%
# plt.figure(figsize=(10,10))
# sns.heatmap(data.corr(),annot=True)
# plt.show()

# %%
y=data['AHD']
data=data.drop(['Unnamed: 0','AHD'],axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calculate(data):
    vif=[]
    output=pd.DataFrame()
    output['Attribute']=data.columns
    for i in range(0,data.shape[1]):
        vif.append(variance_inflation_factor(data,i))
    output['vif']=vif
    return output

# %%
calculate(data)
# Out:
#     Attribute        vif
# 0         Age  42.646138
# 1         Sex   3.364649
# 2   ChestPain   5.081739
# 3      RestBP  64.680578
# 4        Chol  29.907175
# 5         Fbs   1.231247
# 6     RestECG   2.179904
# 7       MaxHR  38.408260
# 8       ExAng   1.891928
# 9     Oldpeak   3.324243
# 10      Slope  11.339734
# 11         Ca   1.985716
# 12       Thal   6.992607

# %%
# data=data.drop(['Age','RestBP','Chol','MaxHR','Slope'],axis=1)
data=data.drop(['RestBP'],axis=1)

# %%
data.head()
# Out:
#    Age  Sex  ChestPain   Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope  \
# 0   63    1          0  233.0    1        2  150.0    0.0      2.3      3
# 1   67    1          1  286.0    0        2  108.0    1.0      1.5      2
# 2   67    1          1  229.0    0        2  129.0    1.0      2.6      2
# 3   37    1          2  250.0    0        0  187.0    0.0      3.5      3
# 4   41    0          3  204.0    0        2  172.0    0.0      1.4      1
#
#     Ca  Thal
# 0  0.0     0
# 1  3.0     1
# 2  2.0     2
# 3  0.0     1
# 4  0.0     1

# %%
calculate(data)
# Out:
#     Attribute        vif
# 0         Age  31.541375
# 1         Sex   3.360072
# 2   ChestPain   5.079559
# 3        Chol  29.161554
# 4         Fbs   1.216440
# 5     RestECG   2.173238
# 6       MaxHR  29.018129
# 7       ExAng   1.879607
# 8     Oldpeak   3.296147
# 9       Slope  11.126255
# 10         Ca   1.975157
# 11       Thal   6.975294

# %%
data=data.drop(['Age'],axis=1)

# %%
calculate(data)
# Out:
#     Attribute        vif
# 0         Sex   3.358394
# 1   ChestPain   5.062526
# 2        Chol  24.238184
# 3         Fbs   1.210361
# 4     RestECG   2.165831
# 5       MaxHR  26.188798
# 6       ExAng   1.875803
# 7     Oldpeak   3.295742
# 8       Slope  10.156693
# 9          Ca   1.817173
# 10       Thal   6.911192

# %%
calculate(data)
# Out:
#     Attribute        vif
# 0         Sex   3.358394
# 1   ChestPain   5.062526
# 2        Chol  24.238184
# 3         Fbs   1.210361
# 4     RestECG   2.165831
# 5       MaxHR  26.188798
# 6       ExAng   1.875803
# 7     Oldpeak   3.295742
# 8       Slope  10.156693
# 9          Ca   1.817173
# 10       Thal   6.911192

# %%
data=data.drop(['MaxHR'],axis=1)

# %%
calculate(data)
# Out:
#    Attribute        vif
# 0        Sex   3.115351
# 1  ChestPain   4.414352
# 2       Chol  13.599474
# 3        Fbs   1.208812
# 4    RestECG   2.164107
# 5      ExAng   1.801910
# 6    Oldpeak   3.248737
# 7      Slope   9.809910
# 8         Ca   1.784341
# 9       Thal   6.659506

# %%
data=data.drop(['Chol'],axis=1)

# %%
calculate(data)
# Out:
#    Attribute       vif
# 0        Sex  3.112613
# 1  ChestPain  3.295996
# 2        Fbs  1.208302
# 3    RestECG  2.018355
# 4      ExAng  1.789078
# 5    Oldpeak  3.223344
# 6      Slope  8.164994
# 7         Ca  1.743843
# 8       Thal  5.580397

# %%
data=data.drop(['Slope'],axis=1)

# %%
calculate(data)
# Out:
#    Attribute       vif
# 0        Sex  3.074668
# 1  ChestPain  2.687094
# 2        Fbs  1.198523
# 3    RestECG  1.901072
# 4      ExAng  1.748992
# 5    Oldpeak  2.274272
# 6         Ca  1.740962
# 7       Thal  5.067392

# %%
X=data

# %%
X.head()
# Out:
#    Sex  ChestPain  Fbs  RestECG  ExAng  Oldpeak   Ca  Thal
# 0    1          0    1        2    0.0      2.3  0.0     0
# 1    1          1    0        2    1.0      1.5  3.0     1
# 2    1          1    0        2    1.0      2.6  2.0     2
# 3    1          2    0        0    0.0      3.5  0.0     1
# 4    0          3    0        2    0.0      1.4  0.0     1

# %%
y.head()
# Out:
# 0     No
# 1    Yes
# 2    Yes
# 3     No
# 4     No
# Name: AHD, dtype: object

# %%
X.describe()
# Out:
#               Sex   ChestPain         Fbs     RestECG       ExAng     Oldpeak  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.676768    1.531987    0.144781    0.996633    0.326599    1.040067
# std      0.468500    0.858082    0.352474    0.994914    0.469761    1.114574
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    1.000000    0.000000    1.000000    0.000000    0.800000
# 75%      1.000000    2.000000    0.000000    2.000000    1.000000    1.600000
# max      1.000000    3.000000    1.000000    2.000000    1.000000    4.000000
#
#                Ca        Thal
# count  297.000000  297.000000
# mean     0.676768    1.326599
# std      0.938965    0.585061
# min      0.000000    0.000000
# 25%      0.000000    1.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# max      3.000000    2.000000

# %%
y.describe()
# Out:
# count     297
# unique      2
# top        No
# freq      160
# Name: AHD, dtype: object

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
X_trans=ss.fit_transform(X)

# %% [markdown]
# # Splitting data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_trans,y,test_size=0.3,random_state=42,stratify=y)

# %%
# print(X_train)

# %% [markdown]
# # Model Build

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate

# %%
rf=RandomForestClassifier( n_estimators=300,random_state=42,class_weight="balanced")
result=cross_validate(rf,X_train,y_train)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300,
#                        random_state=42)

# %%
result['test_score'].mean()
# Out:
# np.float64(0.8066202090592334)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
test_pred=rf.predict(X_test)
print('Accuracy:',accuracy_score(y_test,test_pred))
# Out:
# Accuracy: 0.7444444444444445

# %%
print(confusion_matrix(y_test, test_pred))
# Out:
# [[41  7]
#  [16 26]]

# %%
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.72      0.85      0.78        48
#          Yes       0.79      0.62      0.69        42
#
#     accuracy                           0.74        90
#    macro avg       0.75      0.74      0.74        90
# weighted avg       0.75      0.74      0.74        90
