# %% [markdown]
# ## Build a model to find whether the person is devfaulter or not when income & balance of the person is provided

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Collection

# %%
data=pd.read_csv('Datasets/Default.csv')

# %%
data.head()
# Out:
#   default student      balance       income
# 0      No      No   729.526495  44361.62507
# 1      No     Yes   817.180407  12106.13470
# 2      No      No  1073.549164  31767.13895
# 3      No      No   529.250605  35704.49394
# 4      No      No   785.655883  38463.49588

# %% [markdown]
# ## EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   default  10000 non-null  object
#  1   student  10000 non-null  object
#  2   balance  10000 non-null  float64
#  3   income   10000 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 312.6+ KB

# %%
data['default'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['student'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
plt.boxplot(data['balance'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29614979bd0>,
#   <matplotlib.lines.Line2D at 0x29614979d10>],
#  'caps': [<matplotlib.lines.Line2D at 0x29614979e50>,
#   <matplotlib.lines.Line2D at 0x29614979f90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x296148a1a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2961497a0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2961497a210>],
#  'means': []}

# %%
q3=data['balance'].quantile(0.75)
q1=data['balance'].quantile(0.25)
iqr=q3-q1
upper=q3+1.5*iqr
upper
# Out:
# np.float64(2193.1743093)

# %%
data[data['balance']>upper].count()
# Out:
# default    31
# student    31
# balance    31
# income     31
# dtype: int64

# %%
data.describe()
# Out:
#             balance        income
# count  10000.000000  10000.000000
# mean     835.374886  33516.981876
# std      483.714985  13336.639563
# min        0.000000    771.967729
# 25%      481.731105  21340.462905
# 50%      823.636973  34552.644800
# 75%     1166.308387  43807.729275
# max     2654.322576  73554.233500

# %%
plt.boxplot(data['income'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29614b76e90>,
#   <matplotlib.lines.Line2D at 0x29614b76fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x29614b77110>,
#   <matplotlib.lines.Line2D at 0x29614b77250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x29614b76d50>],
#  'medians': [<matplotlib.lines.Line2D at 0x29614b77390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29614b774d0>],
#  'means': []}

# %%
data=data.drop(data[data['balance']>upper].index)

# %%
data.shape
# Out:
# (9969, 4)

# %%
plt.scatter(data['balance'],data['income'])

# %%
data.head()
# Out:
#   default student      balance       income
# 0      No      No   729.526495  44361.62507
# 1      No     Yes   817.180407  12106.13470
# 2      No      No  1073.549164  31767.13895
# 3      No      No   529.250605  35704.49394
# 4      No      No   785.655883  38463.49588

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['student']=le.fit_transform(data['student'])
data['default']=le.fit_transform(data['default'])

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Feature Engineering

# %%
# X=data.drop('default',axis=1).values
# y=data['default'].values
X=data.drop('default',axis=1)
y=data['default']

# %%
X.head()
# Out:
#    student      balance       income
# 0        0   729.526495  44361.62507
# 1        1   817.180407  12106.13470
# 2        0  1073.549164  31767.13895
# 3        0   529.250605  35704.49394
# 4        0   785.655883  38463.49588

# %%
y.shape
# Out:
# (9969,)

# %%
X.shape
# Out:
# (9969, 3)

# %% [markdown]
# ## Splitting data for training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# ## Build Model

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %% [markdown]
# ## Train model

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Evaluate Model: Testing model

# %%
test_pred=knn.predict(X_test)
test_pred.size
# Out:
# 2991

# %% [markdown]
# ## Check Accuracy

# %%
from sklearn.metrics import accuracy_score, precision_score

# %%
accuracy_score(y_test,test_pred)
# Out:
# 0.9715814108993648

# %%
precision_score(y_test,test_pred)
# Out:
# 0.8933708567854909

# %%
y_test.value_counts()
# Out:
# default
# 1    2919
# 0    2879
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,test_pred)
# Out:
# array([[2538,  341],
#        [  62, 2857]])

# %%
test_acc=[]
train_acc=[]
k=[]
for i in range(3,16,2):
    k.append(i)
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    train_pred=knn.predict(X_train)
    test_pred=knn.predict(X_test)
    test_acc.append(accuracy_score(y_test,test_pred))
    train_acc.append(accuracy_score(y_train,train_pred))

# %%
print(test_acc)
# Out:
# [0.931010693342532, 0.9313556398758193, 0.9304932735426009, 0.9285960676095205, 0.9254915488099345, 0.9242842359434288, 0.9249741290100034]

# %%
print(train_acc)
# Out:
# [0.9587461185864261, 0.9471388437084134, 0.9432943959781163, 0.9391542214993346, 0.9356055005175218, 0.93346148159101, 0.9310956676031347]

# %%
plt.figure(figsize=(10,4))
plt.plot(k,train_acc)
plt.plot(k,test_acc)
plt.xticks(k)
plt.legend(['Training','Testing'])

# %%
data['default'].value_counts()
# Out:
# default
# 0    9662
# 1     307
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %%
X_sm,y_sm=sm.fit_resample(X,y)

# %%
X_sm.shape
# Out:
# (19324, 3)

# %%
X.shape
# Out:
# (9969, 3)

# %%
y.value_counts()
# Out:
# default
# 0    9662
# 1     307
# Name: count, dtype: int64

# %%
y_sm.value_counts()
# Out:
# default
# 0    9662
# 1    9662
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X_sm,y_sm,test_size=0.2,random_state=42)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
knn=KNeighborsClassifier(n_neighbors=7,metric='euclidean')
knn.fit(X_train,y_train)
test_pred=knn.predict(X_test)
print(classification_report(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93      1927
#            1       0.89      0.98      0.93      1938
#
#     accuracy                           0.93      3865
#    macro avg       0.93      0.93      0.93      3865
# weighted avg       0.93      0.93      0.93      3865

# %%
confusion_matrix(y_test,test_pred)
# Out:
# array([[1698,  229],
#        [  43, 1895]])
