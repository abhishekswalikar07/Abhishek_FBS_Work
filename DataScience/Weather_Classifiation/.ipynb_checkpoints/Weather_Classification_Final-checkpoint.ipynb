# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import pickle

# %%
data=pd.read_csv('../Weather_Classifiation/weather_classification_data.csv')

# %%
data.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0        73         9.5               82.0  partly cloudy
# 1         39.0        96         8.5               71.0  partly cloudy
# 2         30.0        64         7.0               16.0          clear
# 3         38.0        83         1.5               82.0          clear
# 4         27.0        74        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2  Winter              3.5    inland
# 1               1011.43         7  Spring             10.0    inland
# 2               1018.72         5  Spring              5.5  mountain
# 3               1026.25         7  Spring              1.0   coastal
# 4                990.67         1  Winter              2.5  mountain
#
#   Weather Type
# 0        Rainy
# 1       Cloudy
# 2        Sunny
# 3        Sunny
# 4        Rainy

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature           13200 non-null  float64
#  1   Humidity              13200 non-null  int64
#  2   Wind Speed            13200 non-null  float64
#  3   Precipitation (%)     13200 non-null  float64
#  4   Cloud Cover           13200 non-null  object
#  5   Atmospheric Pressure  13200 non-null  float64
#  6   UV Index              13200 non-null  int64
#  7   Season                13200 non-null  object
#  8   Visibility (km)       13200 non-null  float64
#  9   Location              13200 non-null  object
#  10  Weather Type          13200 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.1+ MB

# %%
data['Weather Type'].unique()
# Out:
# array(['Rainy', 'Cloudy', 'Sunny', 'Snowy'], dtype=object)

# %%
data['Weather Type'].value_counts()
# Out:
# Weather Type
# Rainy     3300
# Cloudy    3300
# Sunny     3300
# Snowy     3300
# Name: count, dtype: int64

# %%
data['Cloud Cover'].unique()
# Out:
# array(['partly cloudy', 'clear', 'overcast', 'cloudy'], dtype=object)

# %%
data['Season'].unique()
# Out:
# array(['Winter', 'Spring', 'Summer', 'Autumn'], dtype=object)

# %%
data['Location'].unique()
# Out:
# array(['inland', 'mountain', 'coastal'], dtype=object)

# %%
data.describe()
# Out:
#         Temperature      Humidity    Wind Speed  Precipitation (%)  \
# count  13200.000000  13200.000000  13200.000000       13200.000000
# mean      19.127576     68.710833      9.832197          53.644394
# std       17.386327     20.194248      6.908704          31.946541
# min      -25.000000     20.000000      0.000000           0.000000
# 25%        4.000000     57.000000      5.000000          19.000000
# 50%       21.000000     70.000000      9.000000          58.000000
# 75%       31.000000     84.000000     13.500000          82.000000
# max      109.000000    109.000000     48.500000         109.000000
#
#        Atmospheric Pressure      UV Index  Visibility (km)
# count          13200.000000  13200.000000     13200.000000
# mean            1005.827896      4.005758         5.462917
# std               37.199589      3.856600         3.371499
# min              800.120000      0.000000         0.000000
# 25%              994.800000      1.000000         3.000000
# 50%             1007.650000      3.000000         5.000000
# 75%             1016.772500      7.000000         7.500000
# max             1199.210000     14.000000        20.000000

# %%
data.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0        73         9.5               82.0  partly cloudy
# 1         39.0        96         8.5               71.0  partly cloudy
# 2         30.0        64         7.0               16.0          clear
# 3         38.0        83         1.5               82.0          clear
# 4         27.0        74        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2  Winter              3.5    inland
# 1               1011.43         7  Spring             10.0    inland
# 2               1018.72         5  Spring              5.5  mountain
# 3               1026.25         7  Spring              1.0   coastal
# 4                990.67         1  Winter              2.5  mountain
#
#   Weather Type
# 0        Rainy
# 1       Cloudy
# 2        Sunny
# 3        Sunny
# 4        Rainy

# %%
data['Cloud Cover']=data['Cloud Cover'].replace({'partly cloudy':0, 'clear':1, 'overcast':2, 'cloudy':3})
data['Season']=data['Season'].replace({'Winter':0, 'Spring':1, 'Summer':2, 'Autumn':3})
data['Location']=data['Location'].replace({'inland':0, 'mountain':1, 'coastal':2})
data['Weather Type']=data['Weather Type'].replace({'Rainy':0, 'Cloudy':1, 'Sunny':2, 'Snowy':3})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6160\2688886314.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Cloud Cover']=data['Cloud Cover'].replace({'partly cloudy':0, 'clear':1, 'overcast':2, 'cloudy':3})
# C:\Users\User\AppData\Local\Temp\ipykernel_6160\2688886314.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Season']=data['Season'].replace({'Winter':0, 'Spring':1, 'Summer':2, 'Autumn':3})
# C:\Users\User\AppData\Local\Temp\ipykernel_6160\2688886314.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Location']=data['Location'].replace({'inland':0, 'mountain':1, 'coastal':2})
# C:\Users\User\AppData\Local\Temp\ipykernel_6160\2688886314.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Weather Type']=data['Weather Type'].replace({'Rainy':0, 'Cloudy':1, 'Sunny':2, 'Snowy':3})

# %%
data.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0         14.0        73         9.5               82.0            0
# 1         39.0        96         8.5               71.0            0
# 2         30.0        64         7.0               16.0            1
# 3         38.0        83         1.5               82.0            1
# 4         27.0        74        17.0               66.0            2
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2       0              3.5         0
# 1               1011.43         7       1             10.0         0
# 2               1018.72         5       1              5.5         1
# 3               1026.25         7       1              1.0         2
# 4                990.67         1       0              2.5         1
#
#    Weather Type
# 0             0
# 1             1
# 2             2
# 3             2
# 4             0

# %%
def checkOutliers(data, col):
    plt.figure(figsize=(12,4))   

    plt.subplot(1, 2, 1)
    plt.boxplot(data[col])
    plt.title(f"Boxplot of {col}")
    plt.tight_layout(pad=3)      

    plt.subplot(1, 2, 2)
    sns.histplot(data=data, x=col, kde=True)
    
    mean = data[col].mean()
    std = data[col].std()

    plt.axvline(mean, color='black')
    plt.axvline(mean + 3*std, color='red', linestyle='--')
    plt.axvline(mean - 3*std, color='red', linestyle='--')
    plt.title(f"Histogram of {col}")

    plt.tight_layout(pad=3)      # space between plots
    plt.show()

# %%
def handleOutliers(data,col):
    q3=data[col].quantile(0.75)
    q1=data[col].quantile(0.25)
    iqr=q3-q1
    upper=q3+(1.5*iqr)
    lower=q1-(1.5*iqr)
    data.loc[data[col]>upper,col]=upper
    data.loc[data[col]<lower,col]=lower

# %%
checkOutliers(data,'Temperature')
checkOutliers(data,'Wind Speed')
checkOutliers(data,'Precipitation (%)')
checkOutliers(data,'Atmospheric Pressure')
checkOutliers(data,'Visibility (km)')

# %%
handleOutliers(data,'Temperature')
handleOutliers(data,'Wind Speed')
handleOutliers(data,'Precipitation (%)')
handleOutliers(data,'Atmospheric Pressure')
handleOutliers(data,'Visibility (km)')

# %%
checkOutliers(data,'Temperature')
checkOutliers(data,'Wind Speed')
checkOutliers(data,'Precipitation (%)')
checkOutliers(data,'Atmospheric Pressure')
checkOutliers(data,'Visibility (km)')

# %%
data.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0         14.0        73         9.5               82.0            0
# 1         39.0        96         8.5               71.0            0
# 2         30.0        64         7.0               16.0            1
# 3         38.0        83         1.5               82.0            1
# 4         27.0        74        17.0               66.0            2
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2       0              3.5         0
# 1               1011.43         7       1             10.0         0
# 2               1018.72         5       1              5.5         1
# 3               1026.25         7       1              1.0         2
# 4                990.67         1       0              2.5         1
#
#    Weather Type
# 0             0
# 1             1
# 2             2
# 3             2
# 4             0

# %%
data['Weather Type'].value_counts()
# Out:
# Weather Type
# 0    3300
# 1    3300
# 2    3300
# 3    3300
# Name: count, dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
y=data['Weather Type']
data=data.drop('Weather Type',axis=1)

# %%
data.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0         14.0        73         9.5               82.0            0
# 1         39.0        96         8.5               71.0            0
# 2         30.0        64         7.0               16.0            1
# 3         38.0        83         1.5               82.0            1
# 4         27.0        74        17.0               66.0            2
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location
# 0               1010.82         2       0              3.5         0
# 1               1011.43         7       1             10.0         0
# 2               1018.72         5       1              5.5         1
# 3               1026.25         7       1              1.0         2
# 4                990.67         1       0              2.5         1

# %%
def calculate(data):
    vif=[]
    output=pd.DataFrame()
    output['Attribute']=data.columns
    for i in range(0,data.shape[1]):
        vif.append(variance_inflation_factor(data,i))
    output['vif']=vif
    return output

# %%
calculate(data)
# Out:
#               Attribute        vif
# 0           Temperature   3.212472
# 1              Humidity  24.095050
# 2            Wind Speed   4.567860
# 3     Precipitation (%)   7.829748
# 4           Cloud Cover   2.832913
# 5  Atmospheric Pressure  34.682418
# 6              UV Index   2.777295
# 7                Season   2.389741
# 8       Visibility (km)   6.302974
# 9              Location   2.426453

# %%
data=data.drop('Atmospheric Pressure',axis=1)

# %%
calculate(data)
# Out:
#            Attribute        vif
# 0        Temperature   3.154040
# 1           Humidity  12.802287
# 2         Wind Speed   4.539799
# 3  Precipitation (%)   7.821818
# 4        Cloud Cover   2.668112
# 5           UV Index   2.670797
# 6             Season   2.367208
# 7    Visibility (km)   4.228657
# 8           Location   2.360163

# %%
data=data.drop('Humidity',axis=1)

# %%
calculate(data)
# Out:
#            Attribute       vif
# 0        Temperature  3.062390
# 1         Wind Speed  4.122836
# 2  Precipitation (%)  4.468029
# 3        Cloud Cover  2.583530
# 4           UV Index  2.661419
# 5             Season  2.363392
# 6    Visibility (km)  3.772416
# 7           Location  2.322402

# %%
data.describe()
# Out:
#         Temperature    Wind Speed  Precipitation (%)   Cloud Cover  \
# count  13200.000000  13200.000000       13200.000000  13200.000000
# mean      19.050606      9.624924          53.644394      1.178182
# std       17.108668      6.214032          31.946541      0.948516
# min      -25.000000      0.000000           0.000000      0.000000
# 25%        4.000000      5.000000          19.000000      0.000000
# 50%       21.000000      9.000000          58.000000      1.000000
# 75%       31.000000     13.500000          82.000000      2.000000
# max       71.500000     26.250000         109.000000      3.000000
#
#            UV Index        Season  Visibility (km)      Location
# count  13200.000000  13200.000000     13200.000000  13200.000000
# mean       4.005758      1.142576         5.382292      0.905682
# std        3.856600      1.162385         3.105118      0.791537
# min        0.000000      0.000000         0.000000      0.000000
# 25%        1.000000      0.000000         3.000000      0.000000
# 50%        3.000000      1.000000         5.000000      1.000000
# 75%        7.000000      2.000000         7.500000      2.000000
# max       14.000000      3.000000        14.250000      2.000000

# %%
X=data

# %%
X.head()
# Out:
#    Temperature  Wind Speed  Precipitation (%)  Cloud Cover  UV Index  Season  \
# 0         14.0         9.5               82.0            0         2       0
# 1         39.0         8.5               71.0            0         7       1
# 2         30.0         7.0               16.0            1         5       1
# 3         38.0         1.5               82.0            1         7       1
# 4         27.0        17.0               66.0            2         1       0
#
#    Visibility (km)  Location
# 0              3.5         0
# 1             10.0         0
# 2              5.5         1
# 3              1.0         2
# 4              2.5         1

# %%
y.value_counts()
# Out:
# Weather Type
# 0    3300
# 1    3300
# 2    3300
# 3    3300
# Name: count, dtype: int64

# %% [markdown]
# # Splitting data into training and testing

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print("Training Size:", X_train.shape)
print("Testing Size:", X_test.shape)
# Out:
# Training Size: (9240, 8)
# Testing Size: (3960, 8)

# %% [markdown]
# # Scaling

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
data.describe()
# Out:
#         Temperature    Wind Speed  Precipitation (%)   Cloud Cover  \
# count  13200.000000  13200.000000       13200.000000  13200.000000
# mean      19.050606      9.624924          53.644394      1.178182
# std       17.108668      6.214032          31.946541      0.948516
# min      -25.000000      0.000000           0.000000      0.000000
# 25%        4.000000      5.000000          19.000000      0.000000
# 50%       21.000000      9.000000          58.000000      1.000000
# 75%       31.000000     13.500000          82.000000      2.000000
# max       71.500000     26.250000         109.000000      3.000000
#
#            UV Index        Season  Visibility (km)      Location
# count  13200.000000  13200.000000     13200.000000  13200.000000
# mean       4.005758      1.142576         5.382292      0.905682
# std        3.856600      1.162385         3.105118      0.791537
# min        0.000000      0.000000         0.000000      0.000000
# 25%        1.000000      0.000000         3.000000      0.000000
# 50%        3.000000      1.000000         5.000000      1.000000
# 75%        7.000000      2.000000         7.500000      2.000000
# max       14.000000      3.000000        14.250000      2.000000

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf = RandomForestClassifier(random_state=42)

# %%
param_grid_rf = { "n_estimators": [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200],
                  "criterion": ["gini", "entropy"]}

# %%
grid_search_rf = GridSearchCV( estimator=rf, param_grid=param_grid_rf, n_jobs=-1)

# %%
grid_search_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': [100, 200, 300, 400, 500, 600, 700,
#                                           800, 900, 1000, 1100, 1200]})

# %%
print("Best n_estimators:", grid_search_rf.best_params_)
# Out:
# Best n_estimators: {'criterion': 'entropy', 'n_estimators': 400}

# %%
from sklearn.model_selection import cross_validate

# %%
rf = RandomForestClassifier(criterion='entropy', n_estimators=400)
result = cross_validate(rf, X_train, y_train)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=400)

# %%
result['test_score'].mean()
# Out:
# np.float64(0.908874458874459)

# %%
# from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
test_pred = rf.predict(X_test)
accuracy_score(y_test, test_pred)
# Out:
# 0.9045454545454545

# %%
confusion_matrix(y_test, test_pred)
# Out:
# array([[886,  48,  22,  26],
#        [ 49, 851,  30,  25],
#        [ 30,  64, 878,  18],
#        [ 19,  28,  19, 967]])

# %%
print(classification_report(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       982
#            1       0.86      0.89      0.87       955
#            2       0.93      0.89      0.91       990
#            3       0.93      0.94      0.93      1033
#
#     accuracy                           0.90      3960
#    macro avg       0.90      0.90      0.90      3960
# weighted avg       0.91      0.90      0.90      3960

# %% [markdown]
# # User testing

# %%
# Cloud_Cover={'partly cloudy':0, 'clear':1, 'overcast':2, 'cloudy':3}
# Season={'Winter':0, 'Spring':1, 'Summer':2, 'Autumn':3}
# Location_dict={'inland':0, 'mountain':1, 'coastal':2}
# Weather_Type={'Rainy':0, 'Cloudy':1, 'Sunny':2, 'Snowy':3}

# %%
# def predict_weather():
#     print("\n====== ENTER WEATHER DETAILS ======\n")
    
#     print("Cloud cover option: partly cloudy, clear, overcast, cloudy")
#     cloud = input("Enter Colud cover type : ")

#     print("\nSeason options: Winter, Spring, Summer, Autumn")
#     season_type = input("Enter Season Type: ")

#     print("\nLocation options: inland, mountain, coastal")
#     location = input("Enter Location: ")

#     print("\nWeather Type options: Rainy, Cloudy, Sunny, Snowy")
#     weather = input("Enter Weather type: ")

#     temperature=float(input("\nTemperature:"))
#     Wind_Speed=float(input("\nWind Speed:"))
#     Precipitation=float(input("\nPrecipitation %:"))
#     UV_Index=int(input("\nUV Index:"))
#     Visibility_km=float(input("\nVisibility (KM)"))

#     # conver string ->encoded numbers
#     cloud=Cloud_Cover[cloud]
#     # print(cloud)
#     season_type=Season[season_type]
#     Location_encoded=Location_dict[location]

#     user_data=[[temperature, Wind_Speed,Precipitation,cloud,UV_Index,season_type,Visibility_km,Location_encoded]]
#     user_data_scaled = scaler.transform(user_data)
#     res = rf.predict(user_data_scaled)
#     print(res)
#     print("\n===== RESULT =====")

#     if res == 0:
#         print(" Weather is Rainy... Use umbrella!!!")
#     elif res==1:
#         print(" Cloudy weather... Rain may come!!!")
#     elif res==2:
#         print(" Sunny weather... Sun is here !!!")
#     else:
#         print(" It's snow time.. Snowfall is near!!!")

# %%
# predict_weather()

# %%
import joblib

# Save final tuned model
joblib.dump(rf, "weather_model.pkl")

# Save scaler
joblib.dump(scaler, "scaler.pkl")

print("Model and Scaler saved successfully!")
# Out:
# Model and Scaler saved successfully!
